# %%
# 1. 学生成绩分析
# 场景：某班级的学生成绩数据如下，请完成以下任务：
# ● 计算每位学生的总分和平均分
# ● 找出数学成绩高于90分或英语成绩高于85分的学生
# ● 按总分从高到低排序，并输出前3名学生
import numpy as np
import pandas as pd

data = {
    '姓名': ['张三', '李四', '王五', '赵六', '钱七'],
    '数学': [85, 92, 78, 88, 95],
    '英语': [90, 88, 85, 92, 80],
    '物理': [75, 80, 88, 85, 90]
}
df = pd.DataFrame(data, index=[1, 2, 3, 4, 5], columns=['姓名', '数学', '英语', '物理'])
print(df)
df['总分'] = df[['数学', '英语', '物理']].sum(axis=1)
df['平均分'] = df[['数学', '英语', '物理']].mean(axis=1)
print(df)
print(df[(df['数学'] > 90) | (df['英语'] > 85)]['姓名'])
print(df.nlargest(3, columns='总分')['姓名'])
# 或
print(df.sort_values('总分', ascending=False).head(3))
# Out:
#    姓名  数学  英语  物理
# 1  张三  85  90  75
# 2  李四  92  88  80
# 3  王五  78  85  88
# 4  赵六  88  92  85
# 5  钱七  95  80  90
#    姓名  数学  英语  物理   总分        平均分
# 1  张三  85  90  75  250  83.333333
# 2  李四  92  88  80  260  86.666667
# 3  王五  78  85  88  251  83.666667
# 4  赵六  88  92  85  265  88.333333
# 5  钱七  95  80  90  265  88.333333
# 1    张三
# 2    李四
# 4    赵六
# 5    钱七
# Name: 姓名, dtype: object
#    姓名  数学  英语  物理   总分        平均分
# 4  赵六  88  92  85  265  88.333333
# 5  钱七  95  80  90  265  88.333333
# 2  李四  92  88  80  260  86.666667
#    姓名  数学  英语  物理   总分        平均分
# 4  赵六  88  92  85  265  88.333333
# 5  钱七  95  80  90  265  88.333333
# 2  李四  92  88  80  260  86.666667

# %%
# 2. 销售数据分析
# 场景：某公司销售数据如下，请完成以下任务：
# ● 计算每种产品的总销售额（销售额 = 单价 x 销量）
# ● 找出销售额最高的产品
# ● 按销售额从高到低排序，并输出所有产品信息
data = {
    '产品名称': ['A', 'B', 'C', 'D'],
    '单价': [100, 150, 200, 120],
    '销量': [50, 30, 20, 40]
}
df = pd.DataFrame(data, index=[1, 2, 3, 4])
# print(df)
df['销售额'] = df['单价'] * df['销量']
print(df)
print(df.sort_values('销售额', ascending=False))
print(df.describe())
# Out:
#   产品名称   单价  销量   销售额
# 1    A  100  50  5000
# 2    B  150  30  4500
# 3    C  200  20  4000
# 4    D  120  40  4800
#   产品名称   单价  销量   销售额
# 1    A  100  50  5000
# 4    D  120  40  4800
# 2    B  150  30  4500
# 3    C  200  20  4000
#                单价         销量          销售额
# count    4.000000   4.000000     4.000000
# mean   142.500000  35.000000  4575.000000
# std     43.493295  12.909944   434.932945
# min    100.000000  20.000000  4000.000000
# 25%    115.000000  27.500000  4375.000000
# 50%    135.000000  35.000000  4650.000000
# 75%    162.500000  42.500000  4850.000000
# max    200.000000  50.000000  5000.000000

# %%
# # 3. 电商用户行为分析
# # 场景：某电商平台的用户行为数据如下：
# # 计算每位用户的总消费金额（消费金额 = 商品单价 x 购买数量）
# # 找出消费金额最高的用户，并输出其所有信息
# # 计算所有用户平均消费金额（保留2位小数）
# # 统计电子产品的总购买数量
data = {
    '用户ID': [101, 102, 103, 104, 105],
    '用户名': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    '商品类别': ['电子产品', '服饰', '电子产品', '家居', '服饰'],
    '商品单价': [1200, 300, 800, 150, 200],
    '购买数量': [1, 3, 2, 5, 4]
}

df = pd.DataFrame(data, index=[1, 2, 3, 4, 5])
df['消费金额'] = df['商品单价'] * df['购买数量']
print(df)
print(df.nlargest(1, columns='消费金额'))
print(df['消费金额'].mean(axis=0))
print(df[df['商品类别'] == '电子产品']['购买数量'].sum(axis=0))
# Out:
#    用户ID      用户名  商品类别  商品单价  购买数量  消费金额
# 1   101    Alice  电子产品  1200     1  1200
# 2   102      Bob    服饰   300     3   900
# 3   103  Charlie  电子产品   800     2  1600
# 4   104    David    家居   150     5   750
# 5   105      Eve    服饰   200     4   800
#    用户ID      用户名  商品类别  商品单价  购买数量  消费金额
# 3   103  Charlie  电子产品   800     2  1600
# 1050.0
# 3
